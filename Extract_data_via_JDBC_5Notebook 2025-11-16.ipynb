-- %% [markdown]
-- # Extract Data From Return SQL Table

-- %%
create schema if not exists hive_metastore.bronze;

-- %%
create table if not exists hive_metastore.bronze.refunds
USING JDBC 
options(
  URL 'jdbc:sqlserver://sql-server-for-db.database.windows.net:1433;database=demo-database-for-db',
  dbtable 'refunds',
  user 'bhagyashree',
  password 'jadhav@12'
);

-- %%
select * from hive_metastore.bronze.refunds;
