-- %% [markdown]
-- ## # Set-up Project Environment for Gizmobox Data Lakehouse

-- %% [markdown]
-- # 1. Access the container gizmobox

-- %%
create external location if not exists Ex_lo_gizmobox
URL "abfss://gizmobox@storageaccforunity.dfs.core.windows.net"
WITH (STORAGE CREDENTIAL demo_credential1)
COMMENT 'EXTERNAL LOCATION IS CREATED'

-- %%
%python
files = dbutils.fs.ls(
  "abfss://gizmobox@storageaccforunity.dfs.core.windows.net/"
)
if files:
    display(files)
else:
    print("No files found in the specified directory.")

-- %%
%python
dbutils.fs.ls(
  "abfss://gizmobox@storageaccforunity.dfs.core.windows.net/"
)

-- %%
%python
dbutils.fs.ls('abfss://gizmobox@storageaccforunity.dfs.core.windows.net/landing/')

-- %%
show catalogs;

-- %%
create catalog if not exists gizmobox
     managed location 'abfss://gizmobox@storageaccforunity.dfs.core.windows.net/'
     comment 'catalog for gizmobox';

-- %%
show catalogs;

-- %%
use catalog gizmobox;

-- %%
select current_catalog();

-- %%
create schema if not exists landing
     managed location 'abfss://gizmobox@storageaccforunity.dfs.core.windows.net/';

create schema if not exists bronze
     managed location 'abfss://gizmobox@storageaccforunity.dfs.core.windows.net/';

create schema if not exists silver
     managed location 'abfss://gizmobox@storageaccforunity.dfs.core.windows.net/';

create schema if not exists gold
     managed location 'abfss://gizmobox@storageaccforunity.dfs.core.windows.net/';

-- %%
show schemas;

-- %%
use catalog gizmobox;
use schema landing;

-- %%
CREATE EXTERNAL VOLUME  IF NOT EXISTS operational_data
    LOCATION 'abfss://gizmobox@storageaccforunity.dfs.core.windows.net/landing/operational_data/'
